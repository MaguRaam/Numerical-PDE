# %%
## Project b on eigenvector and get b~dfrom mpl_toolkits.mplot3d import Axes3D
import numpy
from matplotlib import pyplot, cm
# %matplotlib inline

# %%
def plot_2D(x,y,p):
    X, Y = numpy.meshgrid(x, y)
    fig = pyplot.figure(figsize=(11, 7), dpi=100)
    pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
    pyplot.colorbar()
    pyplot.contour(X, Y, p, cmap=cm.viridis)
    pyplot.xlabel('X')
    pyplot.ylabel('Y')

# %% [markdown]
# ## Solve poisson equation
#
# $\nabla^{2}u = -2n^{2}\pi^{2}\sin(n\pi x)\sin(n\pi y)$

# %% [markdown]
# ## Right Handside b

# %%
x = numpy.loadtxt('x.dat')
y = numpy.loadtxt('y.dat')
b = numpy.loadtxt('b.dat')

plot_2D(x,y,b)

# %% [markdown]
# ## Project b on eigenvector and get b~

# %%
btilde = numpy.loadtxt('btilde.dat')

plot_2D(x,y,btilde)

# %% [markdown]
# ## Solve for u~ = b~/$\lambda$

# %%
utilde = numpy.loadtxt('utilde.dat')

plot_2D(x,y,utilde)

# %% [markdown]
# ## Expan u~ using eigen basis and get u

# %%
u = numpy.loadtxt('u.dat')

plot_2D(x,y,u)

# %% [markdown]
# ## Analytical solution
# sin(10πx) cos(10πy)

# %%
uexact = numpy.loadtxt('uexact.dat')

plot_2D(x,y,uexact)

# %%
u-uexact
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  9.88792381e-17,  2.04107800e-17],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  3.53525080e-17],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00, -3.53525080e-17],
#        [ 0.00000000e+00,  9.88792381e-17,  0.00000000e+00, ...,
#          0.00000000e+00, -9.88792381e-17, -2.04107800e-17],
#        [ 0.00000000e+00,  2.04107800e-17,  3.53525080e-17, ...,
#         -3.53525080e-17, -2.04107800e-17, -4.99919928e-32]])
