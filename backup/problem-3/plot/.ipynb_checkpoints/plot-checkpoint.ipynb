# %%
## Project b on eigenvector and get b~dfrom mpl_toolkits.mplot3d import Axes3D
import numpy
from matplotlib import pyplot, cm
# %matplotlib inline

# %%
def plot_2D(x,y,p):
    X, Y = numpy.meshgrid(x, y)
    fig = pyplot.figure(figsize=(11, 7), dpi=100)
    pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
    pyplot.colorbar()
    pyplot.contour(X, Y, p, cmap=cm.viridis)
    pyplot.xlabel('X')
    pyplot.ylabel('Y')

# %% [markdown]
# ## Solve poisson equation
#
# $\nabla^{2}u = -2n^{2}\pi^{2}\sin(n\pi x)\sin(n\pi y)$

# %% [markdown]
# ## Right Handside b

# %%
x = numpy.loadtxt('x.dat')
y = numpy.loadtxt('y.dat')
b = numpy.loadtxt('b.dat')

plot_2D(x,y,b)

# %% [markdown]
# ## Project b on eigenvector and get b~

# %%
btilde = numpy.loadtxt('btilde.dat')

plot_2D(x,y,btilde)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ecf87420e380> in <module>
#       1 btilde = numpy.loadtxt('btilde.dat')
#       2
# ----> 3 plot_2D(x,y,btilde)
#
# <ipython-input-2-70d1d56641e0> in plot_2D(x, y, p)
#       2     X, Y = numpy.meshgrid(x, y)
#       3     fig = pyplot.figure(figsize=(11, 7), dpi=100)
# ----> 4     pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
#       5     pyplot.colorbar()
#       6     pyplot.contour(X, Y, p, cmap=cm.viridis)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2528     __ret = gca().contourf(
#    2529         *args, **({"data": data} if data is not None else {}),
# -> 2530         **kwargs)
#    2531     if __ret._A is not None: sci(__ret)  # noqa
#    2532     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6420     def contourf(self, *args, **kwargs):
#    6421         kwargs['filled'] = True
# -> 6422         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6423         self.autoscale_view()
#    6424         return contours
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     853         self._transform = kwargs.pop('transform', None)
#     854
# --> 855         kwargs = self._process_args(*args, **kwargs)
#     856         self._process_levels()
#     857
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1454                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1455
# -> 1456             x, y, z = self._contour_args(args, kwargs)
#    1457
#    1458             _mask = ma.getmask(z)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1512             args = args[1:]
#    1513         elif Nargs <= 4:
# -> 1514             x, y, z = self._check_xyz(args[:3], kwargs)
#    1515             args = args[3:]
#    1516         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1573             if x.shape != z.shape:
#    1574                 raise TypeError("Shape of x does not match that of z: found "
# -> 1575                                 "{0} instead of {1}.".format(x.shape, z.shape))
#    1576
#    1577             if y.shape != z.shape:
#
# TypeError: Shape of x does not match that of z: found (21, 21) instead of (19, 19).

# %% [markdown]
# ## Solve for u~ = b~/$\lambda$

# %%
utilde = numpy.loadtxt('utilde.dat')

plot_2D(x,y,utilde)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c7b39e429b86> in <module>
#       1 utilde = numpy.loadtxt('utilde.dat')
#       2
# ----> 3 plot_2D(x,y,utilde)
#
# <ipython-input-2-70d1d56641e0> in plot_2D(x, y, p)
#       2     X, Y = numpy.meshgrid(x, y)
#       3     fig = pyplot.figure(figsize=(11, 7), dpi=100)
# ----> 4     pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
#       5     pyplot.colorbar()
#       6     pyplot.contour(X, Y, p, cmap=cm.viridis)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2528     __ret = gca().contourf(
#    2529         *args, **({"data": data} if data is not None else {}),
# -> 2530         **kwargs)
#    2531     if __ret._A is not None: sci(__ret)  # noqa
#    2532     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6420     def contourf(self, *args, **kwargs):
#    6421         kwargs['filled'] = True
# -> 6422         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6423         self.autoscale_view()
#    6424         return contours
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     853         self._transform = kwargs.pop('transform', None)
#     854
# --> 855         kwargs = self._process_args(*args, **kwargs)
#     856         self._process_levels()
#     857
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1454                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1455
# -> 1456             x, y, z = self._contour_args(args, kwargs)
#    1457
#    1458             _mask = ma.getmask(z)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1512             args = args[1:]
#    1513         elif Nargs <= 4:
# -> 1514             x, y, z = self._check_xyz(args[:3], kwargs)
#    1515             args = args[3:]
#    1516         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1573             if x.shape != z.shape:
#    1574                 raise TypeError("Shape of x does not match that of z: found "
# -> 1575                                 "{0} instead of {1}.".format(x.shape, z.shape))
#    1576
#    1577             if y.shape != z.shape:
#
# TypeError: Shape of x does not match that of z: found (21, 21) instead of (19, 19).

# %% [markdown]
# ## Expan u~ using eigen basis and get u

# %%
u = numpy.loadtxt('u.dat')

plot_2D(x,y,u)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f6c5f544bcf2> in <module>
#       1 u = numpy.loadtxt('u.dat')
#       2
# ----> 3 plot_2D(x,y,u)
#
# <ipython-input-2-70d1d56641e0> in plot_2D(x, y, p)
#       2     X, Y = numpy.meshgrid(x, y)
#       3     fig = pyplot.figure(figsize=(11, 7), dpi=100)
# ----> 4     pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
#       5     pyplot.colorbar()
#       6     pyplot.contour(X, Y, p, cmap=cm.viridis)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2528     __ret = gca().contourf(
#    2529         *args, **({"data": data} if data is not None else {}),
# -> 2530         **kwargs)
#    2531     if __ret._A is not None: sci(__ret)  # noqa
#    2532     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6420     def contourf(self, *args, **kwargs):
#    6421         kwargs['filled'] = True
# -> 6422         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6423         self.autoscale_view()
#    6424         return contours
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     853         self._transform = kwargs.pop('transform', None)
#     854
# --> 855         kwargs = self._process_args(*args, **kwargs)
#     856         self._process_levels()
#     857
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1454                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1455
# -> 1456             x, y, z = self._contour_args(args, kwargs)
#    1457
#    1458             _mask = ma.getmask(z)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1512             args = args[1:]
#    1513         elif Nargs <= 4:
# -> 1514             x, y, z = self._check_xyz(args[:3], kwargs)
#    1515             args = args[3:]
#    1516         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1573             if x.shape != z.shape:
#    1574                 raise TypeError("Shape of x does not match that of z: found "
# -> 1575                                 "{0} instead of {1}.".format(x.shape, z.shape))
#    1576
#    1577             if y.shape != z.shape:
#
# TypeError: Shape of x does not match that of z: found (21, 21) instead of (19, 19).

# %% [markdown]
# ## Analytical solution
# sin(10πx) cos(10πy)

# %%
uexact = numpy.loadtxt('uexact.dat')

plot_2D(x,y,uexact)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4f86536fc1a5> in <module>
#       1 uexact = numpy.loadtxt('uexact.dat')
#       2
# ----> 3 plot_2D(x,y,uexact)
#
# <ipython-input-2-70d1d56641e0> in plot_2D(x, y, p)
#       2     X, Y = numpy.meshgrid(x, y)
#       3     fig = pyplot.figure(figsize=(11, 7), dpi=100)
# ----> 4     pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
#       5     pyplot.colorbar()
#       6     pyplot.contour(X, Y, p, cmap=cm.viridis)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2528     __ret = gca().contourf(
#    2529         *args, **({"data": data} if data is not None else {}),
# -> 2530         **kwargs)
#    2531     if __ret._A is not None: sci(__ret)  # noqa
#    2532     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6420     def contourf(self, *args, **kwargs):
#    6421         kwargs['filled'] = True
# -> 6422         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6423         self.autoscale_view()
#    6424         return contours
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     853         self._transform = kwargs.pop('transform', None)
#     854
# --> 855         kwargs = self._process_args(*args, **kwargs)
#     856         self._process_levels()
#     857
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1454                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1455
# -> 1456             x, y, z = self._contour_args(args, kwargs)
#    1457
#    1458             _mask = ma.getmask(z)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1512             args = args[1:]
#    1513         elif Nargs <= 4:
# -> 1514             x, y, z = self._check_xyz(args[:3], kwargs)
#    1515             args = args[3:]
#    1516         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1573             if x.shape != z.shape:
#    1574                 raise TypeError("Shape of x does not match that of z: found "
# -> 1575                                 "{0} instead of {1}.".format(x.shape, z.shape))
#    1576
#    1577             if y.shape != z.shape:
#
# TypeError: Shape of x does not match that of z: found (21, 21) instead of (19, 19).

# %%
u-uexact
# Out:
# array([[-4.02588591e-01,  9.63846571e-17,  4.02588591e-01,
#         -1.82753251e-16, -4.02588591e-01,  2.66115836e-18,
#          4.02588591e-01, -4.02519969e-16, -4.02588591e-01,
#          2.00781500e-15,  4.02588591e-01,  9.09576553e-16,
#         -4.02588591e-01, -8.87369351e-16,  4.02588591e-01,
#          5.60319223e-16, -4.02588591e-01,  1.94194433e-15,
#          4.02588591e-01],
#        [ 1.97823641e+00, -2.30669069e-16, -1.97823641e+00,
#          2.05149712e-16,  1.97823641e+00, -3.24400311e-15,
#         -1.97823641e+00,  4.12338020e-16,  1.97823641e+00,
#         -2.41159872e-15, -1.97823641e+00,  4.20453335e-15,
#          1.97823641e+00, -4.01764975e-15, -1.97823641e+00,
#         -2.33286575e-15,  1.97823641e+00, -1.23770365e-16,
#         -1.97823641e+00],
#        [-4.05829547e-07, -3.72365189e-17,  4.05829547e-07,
#          1.67905956e-17, -4.05829547e-07, -4.57997849e-17,
#          4.05829547e-07,  3.71782041e-17, -4.05829547e-07,
#         -2.73198379e-17,  4.05829547e-07,  3.78318682e-17,
#         -4.05829547e-07, -8.79494629e-18,  4.05829547e-07,
#          2.50871309e-18, -4.05829547e-07, -3.76891443e-17,
#          4.05829547e-07],
