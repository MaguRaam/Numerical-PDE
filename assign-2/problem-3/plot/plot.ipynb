# %%
## Project b on eigenvector and get b~dfrom mpl_toolkits.mplot3d import Axes3D
import numpy
from matplotlib import pyplot, cm
# %matplotlib inline

# %%
def plot_2D(x,y,p):
    X, Y = numpy.meshgrid(x, y)
    fig = pyplot.figure(figsize=(11, 7), dpi=100)
    pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)
    pyplot.colorbar()
    pyplot.contour(X, Y, p, cmap=cm.viridis)
    pyplot.xlabel('X')
    pyplot.ylabel('Y')

# %% [markdown]
# ## Solve poisson equation
#
# $\nabla^{2}u = -2n^{2}\pi^{2}\sin(n\pi x)\sin(n\pi y)$

# %% [markdown]
# ## Right Handside b

# %%
x = numpy.loadtxt('x.dat')
y = numpy.loadtxt('y.dat')
b = numpy.loadtxt('b.dat')

plot_2D(x,y,b)

# %% [markdown]
# ## Project b on eigenvector and get b~

# %%
btilde = numpy.loadtxt('btilde.dat')

plot_2D(x,y,btilde)

# %% [markdown]
# ## Solve for u~ = b~/$\lambda$

# %%
utilde = numpy.loadtxt('utilde.dat')

plot_2D(x,y,utilde)

# %% [markdown]
# ## Expan u~ using eigen basis and get u

# %%
u = numpy.loadtxt('u.dat')

plot_2D(x,y,u)

# %% [markdown]
# ## Analytical solution
# sin(10πx) cos(10πy)

# %%
uanalytic = numpy.sin(10*pi*x)*cos(10*pi*y)
plot_2D(x,y,utilde)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3cd450f02db6> in <module>
# ----> 1 uanalytic = numpy.sin(10*pi*x)*cos(10*pi*y)
#       2 plot_2D(x,y,utilde)
#
# NameError: name 'pi' is not defined
