# %%
import numpy as numpy
from matplotlib import pyplot

# %%
u = numpy.loadtxt("u.dat")
pyplot.plot(u)

# %%
uexact = numpy.loadtxt("uexact.dat")
pyplot.plot(uexact)

# %%
q = numpy.loadtxt("q.dat")
pyplot.plot(q)
